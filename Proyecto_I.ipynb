# %% [markdown]
# ## Ejercicio Exploratory Data Analysis
#     - Proyecto 1

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('vgsales.csv')

# %% [markdown]
# ### Exploración básica

# %%
# Primeros 5 registros
df.head(5)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# Ultimos registros
df.tail(5)
# Out:
#         Rank                                              Name Platform  \
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16593  2002.0  Platform       Kemco      0.01      0.00       0.0
# 16594  2003.0   Shooter  Infogrames      0.01      0.00       0.0
# 16595  2008.0    Racing  Activision      0.00      0.00       0.0
# 16596  2010.0    Puzzle    7G//AMES      0.00      0.01       0.0
# 16597  2003.0  Platform     Wanadoo      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales
# 16593          0.0          0.01
# 16594          0.0          0.01
# ...

# %%
# Sampleo de 5 registros 
df.sample(5)
# Out:
#         Rank                                   Name Platform    Year  \
# 14995  14998           Bugriders: The Race of Kings       PS  1997.0
# 5263    5265  CSI: Deadly Intent - The Hidden Cases       DS  2009.0
# 4878    4880                        Just Dance 2014      PS3  2013.0
# 2996    2998                         FIFA Soccer 06       XB  2005.0
# 1977    1979                 Dragon Ball: XenoVerse      PS4  2015.0
#
#            Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 14995     Racing      GT Interactive      0.01      0.01      0.00
# 5263   Adventure             Ubisoft      0.16      0.16      0.00
# 4878        Misc             Ubisoft      0.17      0.15      0.00
# 2996      Sports     Electronic Arts      0.29      0.38      0.00
# 1977    Fighting  Namco Bandai Games      0.30      0.48      0.12
#
#        Other_Sales  Global_Sales
# 14995         0.00          0.02
# 5263          0.04          0.35
# 4878          0.07          0.39
# ...

# %%
# Tamaño de DF en filas y columnas
df.shape
# Out:
# (16598, 11)

# %%
# Tipos de datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
# Ver las estadisticas de las columnas
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
df.describe()
# Out:
#           Rank     Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# count 16598.00 16327.00  16598.00  16598.00  16598.00     16598.00
# mean   8300.61  2006.41      0.26      0.15      0.08         0.05
# std    4791.85     5.83      0.82      0.51      0.31         0.19
# min       1.00  1980.00      0.00      0.00      0.00         0.00
# 25%    4151.25  2003.00      0.00      0.00      0.00         0.00
# 50%    8300.50  2007.00      0.08      0.02      0.00         0.01
# 75%   12449.75  2010.00      0.24      0.11      0.04         0.04
# max   16600.00  2020.00     41.49     29.02     10.22        10.57
#
#        Global_Sales
# count      16598.00
# mean           0.54
# std            1.56
# min            0.01
# 25%            0.06
# 50%            0.17
# 75%            0.47
# max           82.74

# %% [markdown]
# ## Totales

# %%
# Total de videojuegos analizados
df.shape [0]
# Out:
# 16598

# %%
# Total de videojuegos analizados (colmnas)
df['Name'].unique()
# Out:
# array(['Wii Sports', 'Super Mario Bros.', 'Mario Kart Wii', ...,
#        'Plushees', 'Woody Woodpecker in Crazy Castle 5', 'Know How 2'],
#       dtype=object)

# %%
# Total de generos analizados (colmnas)
df['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
# Total de generos analizados (números)
N_genre = df['Genre'].unique().__len__()
N_genre
# Out:
# 12

# %%
# Total de plataformas analizadas (colmnas)
df['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
# Número de plataformas analizadas
n_platform = df['Platform'].unique().__len__()
n_platform
# Out:
# 31

# %%
# Look for null values in all columns of the data
print('Tere are', df.isnull().sum().sum(),'missing values')
# Out:
# Tere are 329 missing values

# %% [markdown]
# ## Ventas

# %%
# Ver el número de ventas por año 
# Usando groupby
df.groupby("Year")["Global_Sales"].count()
# Out:
# Year
# 1980.00       9
# 1981.00      46
# 1982.00      36
# 1983.00      17
# 1984.00      14
# 1985.00      14
# 1986.00      21
# 1987.00      16
# 1988.00      15
# 1989.00      17
# 1990.00      16
# 1991.00      41
# 1992.00      43
# 1993.00      60
# 1994.00     121
# 1995.00     219
# 1996.00     263
# 1997.00     289
# 1998.00     379
# 1999.00     338
# 2000.00     349
# 2001.00     482
# 2002.00     829
# 2003.00     775
# 2004.00     763
# 2005.00     941
# 2006.00    1008
# 2007.00    1202
# 2008.00    1428
# 2009.00    1431
# 2010.00    1259
# 2011.00    1139
# 2012.00     657
# 2013.00     546
# 2014.00     582
# 2015.00     614
# 2016.00     344
# 2017.00       3
# 2020.00       1
# Name: Global_Sales, dtype: int64

# %%
df.groupby("Year")["Global_Sales"].count().sort_values(ascending=False)
# Out:
# Year
# 2009.00    1431
# 2008.00    1428
# 2010.00    1259
# 2007.00    1202
# 2011.00    1139
# 2006.00    1008
# 2005.00     941
# 2002.00     829
# 2003.00     775
# 2004.00     763
# 2012.00     657
# 2015.00     614
# 2014.00     582
# 2013.00     546
# 2001.00     482
# 1998.00     379
# 2000.00     349
# 2016.00     344
# 1999.00     338
# 1997.00     289
# 1996.00     263
# 1995.00     219
# 1994.00     121
# 1993.00      60
# 1981.00      46
# 1992.00      43
# 1991.00      41
# 1982.00      36
# 1986.00      21
# 1989.00      17
# 1983.00      17
# 1987.00      16
# 1990.00      16
# 1988.00      15
# 1985.00      14
# 1984.00      14
# 1980.00       9
# 2017.00       3
# 2020.00       1
# Name: Global_Sales, dtype: int64

# %% [markdown]
# - Según este data el año con mas ventas fue el 2009, lo podemos observar en la siguiente gráfica

# %%
# Total de ventas por año, plot
df.groupby("Year")["Global_Sales"].count().plot.bar()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
# Juegos más vendidos por año
df.groupby("Name")["Global_Sales"].count().sort_values(ascending=False)
# Out:
# Name
# Need for Speed: Most Wanted                12
# Ratatouille                                 9
# Madden NFL 07                               9
# FIFA 14                                     9
# LEGO Marvel Super Heroes                    9
#                                            ..
# Import Tuner Challenge (American sales)     1
# Impossible Creatures                        1
# In Cold Blood                               1
# In The Groove                               1
# ¡Shin Chan Flipa en colores!                1
# Name: Global_Sales, Length: 11493, dtype: int64

# %%
# Graficamos los 15 más vendidos
# Cambio a los 10 más vendidos 
# Cabio prueba 2 (12 más vendidos)
df.groupby("Name")["Global_Sales"].mean().sort_values(ascending=False).head(12).plot.barh()
# Out:
# <AxesSubplot:ylabel='Name'>
